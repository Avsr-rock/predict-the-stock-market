# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read Data

# %%
test=["BTC-USD Out of Time Testing 1st Jan 2022 to 4th Feb 2022","NASDAQ Out of Time Data - 1st Jan 2022 to 4th Feb 2022","NSE Out of Time Testing Data - 1st Jan 2022 to 4th Feb 2022"]
data=[]
for i in test :
    data.append(pd.read_csv(r"E:\DATA SCIENCE\0. Data Science _All_resources\All_resources\PDFs\marketprophecy-main\marketprophecy-main\Stock Data\\"+i+".csv"))

# %%
train=["BTC-USD Training Data - 1st Jan 2016 to 1st Jan 2022","NASDAQ Training Data - 1st Jan 2016 to 1st Jan 2022","NSE Training Data - 1st Jan 2016 to 1st Jan 2022"]
data1=[]
for i in train :
    data1.append(pd.read_csv(r"E:\DATA SCIENCE\0. Data Science _All_resources\All_resources\PDFs\marketprophecy-main\marketprophecy-main\Stock Data\\"+i+".csv"))

# %%
df_test=pd.concat(data)
df_train=pd.concat(data1)

# %%
df_test.head()
df_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-01-01  430.721008  436.246002  427.515015  434.334015  434.334015
# 1  2016-01-02  434.622009  436.062012  431.869995  433.437988  433.437988
# 2  2016-01-03  433.578003  433.743011  424.705994  430.010986  430.010986
# 3  2016-01-04  430.061005  434.516998  429.084015  433.091003  433.091003
# 4  2016-01-05  433.069000  434.182007  429.675995  431.959991  431.959991
#
#        Volume
# 0  36278900.0
# 1  30096600.0
# 2  39633800.0
# 3  38477500.0
# 4  34522600.0

# %% [markdown]
# ### Analysis Data

# %%
df_test.shape
# Out:
# (81, 7)

# %%
df_train.shape
# Out:
# (4933, 7)

# %%
df_test.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df_test.Date.dtype
# Out:
# dtype('O')

# %%
df_test['Date']=pd.to_datetime(df_test.Date)

# %%
df_train['Date']=pd.to_datetime(df_train.Date)

# %%
df_test.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count     81.000000     81.000000     81.000000     81.000000     81.000000
# mean   26874.503328  27223.266192  26273.566045  26748.724778  26748.724778
# std    12648.716257  12901.563358  12204.815168  12533.933584  12533.933584
# min    13436.709961  13765.910156  13094.650391  13352.780273  13352.780273
# 25%    15547.160156  15586.299805  15117.290039  15188.389648  15188.389648
# 50%    18129.199219  18129.199219  17964.400391  18055.750000  18055.750000
# 75%    40699.605469  41060.527344  38113.664063  38743.273438  38743.273438
# max    47680.925781  47881.406250  46856.937500  47686.812500  47686.812500
#
#              Volume
# count  8.100000e+01
# mean   1.378144e+10
# std    1.560722e+10
# min    2.005000e+05
# 25%    3.553000e+05
# 50%    5.111460e+09
# 75%    2.309154e+10
# max    8.419661e+10

# %%
df_train.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   4927.000000   4927.000000   4927.000000   4927.000000   4927.000000
# mean   11019.497254  11205.787316  10810.723870  11025.534914  11025.534914
# std    11357.823086  11677.937987  10994.489203  11365.052117  11365.052117
# min      365.072998    374.950012    354.914001    364.330994    364.330994
# 25%     6205.150147   6256.695068   6125.145019   6198.649170   6198.649170
# 50%     8514.299805   8591.820313   8389.889648   8519.500000   8519.500000
# 75%    11158.958985  11296.775391  11033.795410  11154.125000  11154.125000
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  4.927000e+03
# mean   8.444644e+09
# std    1.616897e+10
# min    0.000000e+00
# 25%    6.061000e+05
# 50%    1.891300e+09
# 75%    6.058675e+09
# max    3.509679e+11

# %%
df_test.info()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 0 to 22
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       81 non-null     datetime64[ns]
#  1   Open       81 non-null     float64
#  2   High       81 non-null     float64
#  3   Low        81 non-null     float64
#  4   Close      81 non-null     float64
#  5   Adj Close  81 non-null     float64
#  6   Volume     81 non-null     int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 5.1 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4933 entries, 0 to 1480
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4933 non-null   datetime64[ns]
#  1   Open       4927 non-null   float64
#  2   High       4927 non-null   float64
#  3   Low        4927 non-null   float64
#  4   Close      4927 non-null   float64
# ...

# %% [markdown]
# **Observations:**
#
# - The test dataset have 81 observation records.
# - The train dataset have 4933 observation records.
# - Check Datatype and Change datatype of Date Variable.
# - Dataset have 7 Column ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# - Check Min,Max,Mean,25%,75%

# %% [markdown]
# ### Check Null Value and Unique Value

# %%
df_test.isnull().mean()
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
df_train.isnull().mean()
# Out:
# Date         0.000000
# Open         0.001216
# High         0.001216
# Low          0.001216
# Close        0.001216
# Adj Close    0.001216
# Volume       0.001216
# dtype: float64

# %%
# Fill Nan Value
df_train['Open'].fillna(method = 'ffill', inplace=True)
df_train['High'].fillna(method = 'bfill',inplace=True)
df_train['Low'].fillna(method = 'bfill',inplace=True)
df_train['Close'].fillna(method = 'bfill',inplace=True)
df_train['Volume'].fillna(method = 'bfill',inplace=True)
df_train['Adj Close'].fillna(method = 'bfill',inplace=True)

# %%
df_train.isnull().mean()
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
print(df_train['Open'].unique())
print(df_train['High'].unique())
print(df_train['Low'].unique())
print(df_train['Close'].unique())
print(df_train['Volume'].unique())
print(df_train['Adj Close'].unique())
# Out:
# [  430.721008   434.622009   433.578003 ... 17220.099609 17201.449219
#  17244.5     ]
# [  436.246002   436.062012   433.743011 ... 17285.949219 17264.050781
#  17400.800781]
# [  427.515015   431.869995   424.705994 ... 17176.650391 17146.349609
#  17238.5     ]
# [  434.334015   433.437988   430.010986 ... 17213.599609 17203.949219
#  17354.050781]
# [36278900. 30096600. 39633800. ...   161700.   320800.   167000.]
# [  434.334015   433.437988   430.010986 ... 17213.599609 17203.949219
#  17354.050781]

# %%
print("Unique values of each columns: ")
for col in df_test.columns:
  print(f"{col}: \n{df_test[col].unique()}\n")
# Out:
# Unique values of each columns:
# Date:
# ['2022-01-01T00:00:00.000000000' '2022-01-02T00:00:00.000000000'
#  '2022-01-03T00:00:00.000000000' '2022-01-04T00:00:00.000000000'
#  '2022-01-05T00:00:00.000000000' '2022-01-06T00:00:00.000000000'
#  '2022-01-07T00:00:00.000000000' '2022-01-08T00:00:00.000000000'
#  '2022-01-09T00:00:00.000000000' '2022-01-10T00:00:00.000000000'
#  '2022-01-11T00:00:00.000000000' '2022-01-12T00:00:00.000000000'
#  '2022-01-13T00:00:00.000000000' '2022-01-14T00:00:00.000000000'
#  '2022-01-15T00:00:00.000000000' '2022-01-16T00:00:00.000000000'
#  '2022-01-17T00:00:00.000000000' '2022-01-18T00:00:00.000000000'
#  '2022-01-19T00:00:00.000000000' '2022-01-20T00:00:00.000000000'
#  '2022-01-21T00:00:00.000000000' '2022-01-22T00:00:00.000000000'
#  '2022-01-23T00:00:00.000000000' '2022-01-24T00:00:00.000000000'
#  '2022-01-25T00:00:00.000000000' '2022-01-26T00:00:00.000000000'
#  '2022-01-27T00:00:00.000000000' '2022-01-28T00:00:00.000000000'
# ...

# %% [markdown]
# **Observations:**
# - No nan Value

# %% [markdown]
# ###  Data Visualization

# %%
df_test.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999632  0.998483  0.998260   0.998260  0.829185
# High       0.999632  1.000000  0.998467  0.998570   0.998570  0.828651
# Low        0.998483  0.998467  1.000000  0.999253   0.999253  0.812066
# Close      0.998260  0.998570  0.999253  1.000000   1.000000  0.815787
# Adj Close  0.998260  0.998570  0.999253  1.000000   1.000000  0.815787
# Volume     0.829185  0.828651  0.812066  0.815787   0.815787  1.000000

# %%
sns.pairplot(df_test)

# %%
# with regression
sns.pairplot(df_test, kind="reg")
plt.show()
 
# without regression
sns.pairplot(df_test, kind="scatter")
plt.show()

# %%
# density plot or histogram
sns.pairplot(df_test, diag_kind="kde", diag_kws=dict(shade=True, bw_adjust=.05, vertical=False) )

# %%
#get correlations of each features in dataset
corrmat = df_test.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_test[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# **Correlation heatmap is graphical representation of correlation matrix representing correlation between different variables.
# The value of correlation can take any values from -1 to 1.**
#
# 1. Green box is Highly +ve Correlated
# 2. red boc is -ve correlated
# 3. If the value is 1, it is said to be positive correlation between two variables. This means that when one variable increases,    the other variable also increases.
# 4. If the value is -1, it is said to be negative correlation between two variables. This means that when one variable
#    increases, the other variable decreases.
# 5. If the value is 0, there is no correlation between two variables. This means that the variables changes in a random manner      with respect to each other.

# %% [markdown]
# ### Model Building
#
# 1. Take Independent and Dependent Variables x,y

# %%
x_test=df_test.drop(['Adj Close','Date'],axis=1)
y_test = df_test['Adj Close']
x_train=df_train.drop(['Adj Close','Date'],axis=1)
y_train = df_train['Adj Close']

# %%
x_test
# Out:
#             Open          High           Low         Close       Volume
# 0   46311.746094  47827.312500  46288.484375  47686.812500  24582667004
# 1   47680.925781  47881.406250  46856.937500  47345.218750  27951569547
# 2   47343.542969  47510.726563  45835.964844  46458.117188  33071628362
# 3   46458.851563  47406.546875  45752.464844  45897.574219  42494677905
# 4   45899.359375  46929.046875  42798.222656  43569.003906  36851084859
# ..           ...           ...           ...           ...          ...
# 18  17208.300781  17373.500000  17077.099609  17101.949219       355300
# 19  17301.050781  17410.000000  17264.150391  17339.849609       321700
# 20  17529.449219  17622.400391  17244.550781  17576.849609       386400
# 21  17706.199219  17794.599609  17674.800781  17780.000000       271200
# 22  17767.750000  17781.150391  17511.150391  17560.199219       226600
#
# [81 rows x 5 columns]

# %%
y_train = df_train['Volume'].astype(float)

# %%
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y_train)

# %% [markdown]
# #### Use Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf=RandomForestRegressor(n_estimators = 100, random_state = 0)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
model_rf.score(x_test,y_test)
# Out:
# -2784691392041.5713

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
# create a regressor object
data = KNeighborsRegressor()

# %%
data.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
data.score(x_test,y_test)
# Out:
# -2769393063506.6943
